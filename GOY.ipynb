# %%
# %matplotlib inline

# %%
import pandas as pd

# %%
! cargo run --release --bin=goy_shell > goy.csv
# Out:
#    Compiling ndarray-odeint v0.2.2 (file:///home/teramura/workspace/ndarray-odeint)
#     Finished release [optimized] target(s) in 2.35 secs
#      Running `target/release/goy_shell`

# %%
df = pd.read_csv("goy.csv").set_index("time")

# %%
df[["r4", "r8", "r16", "r26"]].plot()

# %%
(df**2).mean().plot()
plt.yscale("log")
