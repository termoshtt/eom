# %% [markdown]
# # Covariant Lyapunov Vectors

# %%
# %matplotlib inline

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# A sample script for calculate CLV of Lorenz 63 model is placed at `src/bin/clv.rs`

# %%
! cargo run --release --bin clv > clv.csv
# Out:
#    Compiling ndarray-odeint v0.2.2 (file:///home/teramura/workspace/ndarray-odeint)
#     Finished release [optimized] target(s) in 4.30 secs
#      Running `target/release/clv`
# exponents = [0.9055708184196481, -0.0011857314296355916, -14.57252335125362] shape=[3], strides=[1]

# %% [markdown]
# ## Tangency of CLVs

# %%
df = np.arccos(pd.read_csv("clv.csv"))

# %%
for col in df.columns:
    plt.figure()
    plt.title(col)
    df[col].hist(bins=1000)
    plt.xlim(0, np.pi)

# %% [markdown]
# - Lorenz system with this setting is hyperbolic since no pair of vectors become parallel.
